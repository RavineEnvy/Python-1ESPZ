# %%
#Estrutura com Listas
time = ['A', 'B', 'C'],
vitoria = [10,9,6],
estado = ['SP', 'SP', 'RJ']


#Estutura com Dicionário
dic = {
    'time': ['A', 'B', 'C'],
    'vitoria': [10,9,6],
    'estado': ['SP', 'SP', 'RJ']
}


import pandas as pd

dataFrame=pd.DataFrame(dic)

print(dataFrame)
# Out:
#   time  vitoria estado
# 0    A       10     SP
# 1    B        9     SP
# 2    C        6     RJ

# %%
produto = dict(nome='notebook', preco=2000)
print(produto.get('marca', 'Não informado'))
# Out:
# Não informado

# %%
cliente = {}

cliente['nome'] = input('Digite seu nome: ')
cliente['idade'] = int(input('Digite sua idade: '))


print(cliente)
# Out:
# {'nome': 'Guilherme Freire Pires', 'idade': 26}

# %%
cliente = {'nome': 'Ana', 'idade': 25}
cliente['idade'] = 26
print(cliente)

cliente.update({"tel": "9999-9999"});
print(cliente)


tel = cliente.pop('tel')
print(cliente)
# Out:
# {'nome': 'Ana', 'idade': 26}
# {'nome': 'Ana', 'idade': 26, 'tel': '9999-9999'}
# {'nome': 'Ana', 'idade': 26}

# %%
produto = {'preco': 2000, 'estoque': 1}

if "email" in produto:
    print("Tem email")
else:
    print("Não tem email")

if produto["preco"] > 1000:
    categoria = "Alto valor"

print(categoria)
# Out:
# Não tem email
# Alto valor

# %%
cliente = {"nome": "Ana", "idade": 25}

print(cliente.keys())
print(cliente.values())
print(cliente.items())
# Out:
# dict_keys(['nome', 'idade'])
# dict_values(['Ana', 25])
# dict_items([('nome', 'Ana'), ('idade', 25)])

# %%
#Ex. 1 - Pega o nome e três notas de uma aluno via inpu(), e guarde um dicionário, calcule a média e dusa if para imprimir "Arpovado e "Reprovado.

dicionario = {
    'nome': input('Digite o nome do aluno: '),
    'nota1': float(input('Digite a primeira nota: ')),
    'nota2': float(input('Digite a segunda nota: ')),
    'nota3': float(input('Digite a terceira nota: '))
}

media = (dicionario['nota1'] + dicionario['nota2'] + dicionario['nota3']) / 3

if media >= 7:
    print(f"{dicionario['nome']} está aprovado com média {media:.2f}")
else:
    print(f"{dicionario['nome']} está reprovado com média {media:.2f}")
# Out:
# Guilherme está aprovado com média 7.70

# %%
dic = {}

dic['nome'] = input('Digite seu nome: ')

for i in range(3):
    nota = float(input(f'Digite a nota {i+1}: '))
    dic[f'nota{i+1}'] = nota

media = (dic['nota1'] + dic['nota2'] + dic['nota3'])/3

if media >= 7:
    print(f"O aluno {dic['nome']} foi aprovado com a média de {media:.1f}!")
else:
    print(f"O aluno {dic['nome']} foi reprovado com a média de {media:.1f}!")
# Out:
# O aluno gui foi aprovado com a média de 9.0!

# %%
#Ex. 2 - Crie um dicionário conta com titular e saldo. Peça um valor de saque se maior que o saldo, imprima "Saldo Insuficiente"

# %%
#Ex. 3 - Crie um dicionário livro com páginas_lidas e total_paginas, calcule o percentual lido e classifique com IF

# %%
#Ex. 4 - Usando .get(), verifique se um dicionário cliente tem a chave desconto. se não tiver, aplique 10% por padrão.
