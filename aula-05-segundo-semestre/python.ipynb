# %%
#Ex. 1
def soma_ate(n):
    total = 0
    for i in range(1, n + 1):
        total= total + i
    return total

#Ex. 2
def soma_ate2(n):
    return n * (n + 1) // 2


# %time print(soma_ate(6))
# %time print(soma_ate2(6))
# Out:
# 21
# CPU times: total: 0 ns
# Wall time: 186 μs
# 21
# CPU times: total: 0 ns
# Wall time: 10.7 μs

# %%
import pandas as pd
import matplotlib.pyplot as plt
 
df = pd.DataFrame({
    "pedido":    [1001, 1002, 1003, 1004, 1005, 1006],
    "produto":   ["Notebook", "Mouse", "Monitor",
                  "Teclado", "Notebook", "Webcam"],
    "categoria": ["Informatica", "Acessorio",
                  "Informatica", "Acessorio",
                  "Informatica", "Acessorio"],
    "regiao":    ["SP", "RJ", "SP", "MG", "RJ", "SP"],
    "preco":     [4200.0, 89.9, 1350.0,
                  210.0, 3990.0, 149.9],
    "qtd":       [2, 10, 3, 5, 1, 4],
})

total = []
for i in range(len(df)):
    total.append(df['preco'][i] * df['qtd'][i])
print(total)


#Inserir os valores em uma nova coluna 
df['Total'] = total
print(df['Total'])

#Ex. 4
df['Toltal'] = df["preco"] * df["qtd"]

#Ex. 5

x = df['pedido']
y = df['preco']

plt.bar(x,y)
plt.show()

#Ex. 6
lista_total=[]

for i in range(len(df)):
    if df["Toltal"][i] > 1000:
        lista_total.append(df["Toltal"][i])
print(lista_total)
print('--------------------------------------------------------------------------------')

#Ex. 7

filtro = df['Total'] > 1000
acima = df[filtro]
print(acima)
# Out:
# [np.float64(8400.0), np.float64(899.0), np.float64(4050.0), np.float64(1050.0), np.float64(3990.0), np.float64(599.6)]
# 0    8400.0
# 1     899.0
# 2    4050.0
# 3    1050.0
# 4    3990.0
# 5     599.6
# Name: Total, dtype: float64
# [np.float64(8400.0), np.float64(4050.0), np.float64(1050.0), np.float64(3990.0)]
# --------------------------------------------------------------------------------
#    pedido   produto    categoria regiao   preco  qtd   Total  Toltal
# 0    1001  Notebook  Informatica     SP  4200.0    2  8400.0  8400.0
# 2    1003   Monitor  Informatica     SP  1350.0    3  4050.0  4050.0
# 3    1004   Teclado    Acessorio     MG   210.0    5  1050.0  1050.0
# 4    1005  Notebook  Informatica     RJ  3990.0    1  3990.0  3990.0
